# %%
import pandas as pd

df = pd.read_csv('sample.csv', sep = ';')
df
# Out:
#     Numero billet  Reservation Date reservation Heure reservation  \
# 0         1400222       843989   04/06/15 00:00          16:26:04
# 1         1400223       843990   04/06/15 00:00          16:26:04
# 2         1400225       843991   04/06/15 00:00          16:26:04
# 3         1400228       843992   04/06/15 00:00          16:26:04
# 4         1400229       843986   04/06/15 00:00          16:26:04
# 5         1400231       843994   04/06/15 00:00          16:26:04
# 6         1400233       843993   04/06/15 00:00          16:26:04
# 7         1400235       843987   04/06/15 00:00          16:26:04
# 8         1491869       838354   02/06/15 00:00          10:28:43
# 9         1491870       838354   02/06/15 00:00          10:28:43
# 10        1491871       838375   02/06/15 00:00          10:28:43
# 11        1491872       838453   02/06/15 00:00          10:28:43
# 12        1491873       838453   02/06/15 00:00          10:28:43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 23 columns):
# Numero billet               99 non-null int64
# Reservation                 99 non-null int64
# Date reservation            99 non-null object
# Heure reservation           99 non-null object
# Cle spectacle               99 non-null int64
# Spectacle                   99 non-null object
# Cle representation          99 non-null int64
# Representation              99 non-null object
# Date representation         99 non-null object
# Heure representation        99 non-null object
# Date fin representation     99 non-null object
# Heure fin representation    99 non-null object
# Prix                        99 non-null int64
# Type de produit             99 non-null object
# Filiere de vente            99 non-null object
# Nom                         99 non-null object
# Prenom                      99 non-null object
# Email                       99 non-null object
# ...
